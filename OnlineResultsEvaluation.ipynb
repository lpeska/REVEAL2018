# %%
import pandas as pd
import numpy as np
dfTesting = pd.read_csv("validTestingResults.csv", sep=";", header=0, index_col=None)
dfTesting.head()
# Out:
#    id   userID  objectID  visited_objects             eventType  eventValue  \
# 0  38  2673313       387                2  object_shown_in_list           1
# 1  39  2673313      4911                2  object_shown_in_list           1
# 2  40  2673313      4788                2  object_shown_in_list           1
# 3  41  2673313      6219                2  object_shown_in_list           1
# 4  42  2673313      1687                2  object_shown_in_list           1
#
#      position                 date
# 0  recomended  2018-07-20 17:21:26
# 1  recomended  2018-07-20 17:21:26
# 2  recomended  2018-07-20 17:21:26
# 3  recomended  2018-07-20 17:21:26
# 4  recomended  2018-07-20 17:21:26

# %%
dfIF = pd.read_csv("recent_implicit_feedback.csv", sep=";", header=0, index_col=None)
dfIF.head()
# Out:
#         id   userID  objectID eventType  eventValue         lastModified
# 0  3706361  2705429       263  pageview           1  2018-07-16 00:04:42
# 1  3706364  2705430      5734  pageview           1  2018-07-16 00:07:05
# 2  3706366  2705431       324  pageview           1  2018-07-16 00:11:04
# 3  3706369  2705431       108  pageview           1  2018-07-16 00:11:48
# 4  3706372  2705433       303  pageview           1  2018-07-16 01:03:41

# %%
resOO = pd.read_csv("results_open_object.csv", sep=";", header=0, index_col=0)
resOO.head()
# Out:
#             cnt
# recVariant
# 0            18
# 1            24
# 2            28
# 3            21
# 4            16

# %%
sum(resOO.cnt)
# Out:
# 284

# %%
resSO = pd.read_csv("results_shown_object.csv", sep=";", header=0, index_col=0)
resSO.head()
# Out:
#              cnt
# recVariant
# 0           2802
# 1           3042
# 2           3021
# 3           3130
# 4           3022

# %%
sum(resSO.cnt)
# Out:
# 37390

# %%
resOO["ctr"] = resOO.cnt / resSO.cnt

# %%
merged = pd.merge(dfTesting, dfIF, how='inner', on=("userID", "objectID"))
merged.head()
# Out:
#    id_x   userID  objectID  visited_objects              eventType_x  \
# 0    38  2673313       387                2     object_shown_in_list
# 1    39  2673313      4911                2     object_shown_in_list
# 2   104  2709558       352                1     object_shown_in_list
# 3   116  2709558       352                1  object_opened_from_list
# 4   117  2709558       352                1     object_shown_in_list
#
#    eventValue_x    position                 date     id_y eventType_y  \
# 0             1  recomended  2018-07-20 17:21:26  3712651    pageview
# 1             1  recomended  2018-07-20 17:21:26  3664714    pageview
# 2             1  recomended  2018-07-20 17:37:39  3712985    pageview
# 3             1  recomended  2018-07-20 17:40:32  3712985    pageview
# 4             1  recomended  2018-07-20 17:40:32  3712985    pageview
#
#    eventValue_y         lastModified
# 0             1  2018-07-20 13:06:34
# 1             6  2018-07-20 17:21:27
# 2             3  2018-07-20 17:48:12
# 3             3  2018-07-20 17:48:12
# 4             3  2018-07-20 17:48:12

# %%
import datetime
merged["dateX"] = pd.to_datetime(merged.date)
merged["lastModifiedX"] = pd.to_datetime(merged.lastModified)
merged["dtDiff"] = (merged["lastModifiedX"] - merged["dateX"]).dt.seconds
merged.head()
# Out:
#    id_x   userID  objectID  visited_objects              eventType_x  \
# 0    38  2673313       387                2     object_shown_in_list
# 1    39  2673313      4911                2     object_shown_in_list
# 2   104  2709558       352                1     object_shown_in_list
# 3   116  2709558       352                1  object_opened_from_list
# 4   117  2709558       352                1     object_shown_in_list
#
#    eventValue_x    position                 date     id_y eventType_y  \
# 0             1  recomended  2018-07-20 17:21:26  3712651    pageview
# 1             1  recomended  2018-07-20 17:21:26  3664714    pageview
# 2             1  recomended  2018-07-20 17:37:39  3712985    pageview
# 3             1  recomended  2018-07-20 17:40:32  3712985    pageview
# 4             1  recomended  2018-07-20 17:40:32  3712985    pageview
#
#    eventValue_y         lastModified               dateX       lastModifiedX  \
# 0             1  2018-07-20 13:06:34 2018-07-20 17:21:26 2018-07-20 13:06:34
# 1             6  2018-07-20 17:21:27 2018-07-20 17:21:26 2018-07-20 17:21:27
# 2             3  2018-07-20 17:48:12 2018-07-20 17:37:39 2018-07-20 17:48:12
# 3             3  2018-07-20 17:48:12 2018-07-20 17:40:32 2018-07-20 17:48:12
# 4             3  2018-07-20 17:48:12 2018-07-20 17:40:32 2018-07-20 17:48:12
#
#    dtDiff
# 0   71108
# 1       1
# 2     633
# 3     460
# 4     460

# %%
mergedRestr = merged.loc[(merged.date < merged.lastModified) & (merged.dtDiff > 5) & (merged.eventType_x == "object_shown_in_list") & (merged.visited_objects > 0) & (merged.eventType_y == "pageview")]
mergedRestr.head()
# Out:
#    id_x   userID  objectID  visited_objects           eventType_x  \
# 2   104  2709558       352                1  object_shown_in_list
# 4   117  2709558       352                1  object_shown_in_list
# 5   131  2709558      4330                1  object_shown_in_list
# 6   137  2709558      4330                1  object_shown_in_list
# 7   143  2709558      4330                1  object_shown_in_list
#
#    eventValue_x    position                 date     id_y eventType_y  \
# 2             1  recomended  2018-07-20 17:37:39  3712985    pageview
# 4             1  recomended  2018-07-20 17:40:32  3712985    pageview
# 5             1  recomended  2018-07-20 17:41:54  3713002    pageview
# 6             1  recomended  2018-07-20 17:42:27  3713002    pageview
# 7             1  recomended  2018-07-20 17:42:39  3713002    pageview
#
#    eventValue_y         lastModified               dateX       lastModifiedX  \
# 2             3  2018-07-20 17:48:12 2018-07-20 17:37:39 2018-07-20 17:48:12
# 4             3  2018-07-20 17:48:12 2018-07-20 17:40:32 2018-07-20 17:48:12
# 5             3  2018-07-20 17:47:55 2018-07-20 17:41:54 2018-07-20 17:47:55
# 6             3  2018-07-20 17:47:55 2018-07-20 17:42:27 2018-07-20 17:47:55
# 7             3  2018-07-20 17:47:55 2018-07-20 17:42:39 2018-07-20 17:47:55
#
#    dtDiff
# 2     633
# 4     460
# 5     361
# 6     328
# 7     316

# %%
mergedRestr.shape
# Out:
# (2263, 15)

# %%
(merged.shape, mergedRestr.shape)
# Out:
# ((7068, 15), (2263, 15))

# %%
mergedRestr["recVariant"] = mergedRestr.userID % 12
mergedRestr = mergedRestr[["recVariant","date","lastModified"]]
mergedRestr.head()
# Out:
# C:\Users\peska\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    recVariant                 date         lastModified
# 2           6  2018-07-20 17:37:39  2018-07-20 17:48:12
# 4           6  2018-07-20 17:40:32  2018-07-20 17:48:12
# 5           6  2018-07-20 17:41:54  2018-07-20 17:47:55
# 6           6  2018-07-20 17:42:27  2018-07-20 17:47:55
# 7           6  2018-07-20 17:42:39  2018-07-20 17:47:55

# %%
dfGroup = mergedRestr.groupby(by=["recVariant"])
dfSum = dfGroup.count()
dfSum
# Out:
#             date  lastModified
# recVariant
# 0             99            99
# 1            139           139
# 2            156           156
# 3            136           136
# 4            177           177
# 5             37            37
# 6            443           443
# 7            158           158
# 8            172           172
# 9            117           117
# 10           197           197
# 11           432           432

# %%
resOO["vrr"] = dfSum.date/resSO.cnt

# %%
algVariants = [{"name":"doc2vec", "params": "128,1", "aggregation": "last", "diversity": "no", "novelty": "yes"},
            {"name":"doc2vec", "params": "128,1", "aggregation": "temporal", "diversity": "yes", "novelty": "no"},
            {"name":"doc2vec", "params": "32,5", "aggregation": "mean", "diversity": "no", "novelty": "no"},
            {"name":"doc2vec", "params": "32,5", "aggregation": "mean", "diversity": "yes", "novelty": "no"},
            {"name":"doc2vec", "params": "128,5", "aggregation": "max", "diversity": "no", "novelty": "yes"},
            {"name":"attributeCosineSim", "params": "noSameObjects", "aggregation": "temporal", "diversity": "no", "novelty": "yes"},
            {"name":"attributeCosineSim", "params": "sameAllowed", "aggregation": "mean", "diversity": "no", "novelty": "yes"},
            {"name":"attributeCosineSim", "params": "sameAllowed", "aggregation": "window10", "diversity": "no", "novelty": "no"},
            {"name":"word2vec", "params": "64,5", "aggregation": "mean", "diversity": "yes", "novelty": "no"},
            {"name":"word2vec", "params": "32,5", "aggregation": "temporal", "diversity": "no", "novelty": "yes"},
            {"name":"word2vec", "params": "128,3", "aggregation": "last", "diversity": "no", "novelty": "no"},
            {"name":"word2vec", "params": "32,3", "aggregation": "window10", "diversity": "no", "novelty": "no"}]
#resOO["algorithm"] = algVariants
#resOO

# %%
np.corrcoef(resOO.ctr, resOO.vrr)
# Out:
# array([[1.        , 0.03962154],
#        [0.03962154, 1.        ]])

# %%
from scipy.stats import spearmanr
spearmanr(resOO.ctr, resOO.vrr)
# Out:
# SpearmanrResult(correlation=0.3706293706293707, pvalue=0.2356210035126457)

# %%
#get data from off-line evaluation
df = pd.read_csv("../../resultsWithNovDiv_32_0dot01Temporal.csv", sep=";", header=0, index_col=None)
df.user_novelty5 = 1-df.user_novelty5
df.user_novelty10 = 1-df.user_novelty10
df.mae = -df.mae
df.rename(columns={"r2Score":"R^2", "mae":"-mae", "aucScore":"auc", "nDCGFull":"nDCG", "novelty5":"novelty5_t", "novelty10":"novelty10_t", "user_novelty5":"novelty5_u", "user_novelty10":"novelty10_u"}, inplace=True)
del df["uid"]

# %matplotlib inline
dfGroup = df.groupby(by=["alg","params","recAlg","noveltyEnhance","diversityEnhance"])
dfMean = dfGroup.mean()
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

fig, ax = plt.subplots(figsize=(15, 10))

ax = sns.heatmap(dfMean.corr(method='spearman'), annot=True)
ax.set_xticks(np.asarray(range(len(dfMean.columns)))+0.5, minor=False)
ax.set_xticklabels(dfMean.columns)

ax.set_yticks(np.asarray(range(len(dfMean.columns)))+0.5, minor=False)
ax.set_yticklabels(dfMean.columns)
df = df[["alg","params","recAlg","noveltyEnhance","diversityEnhance","-mae", "auc", "mrr", "nDCG100","novelty10_t","novelty10_u","ild10"]]

# %%
dfGroup = df.groupby(by=["alg","params","recAlg","noveltyEnhance","diversityEnhance"])
dfMean = dfGroup.mean()
dfMean.reset_index(inplace=True)
dfMean.head()
# Out:
#                   alg         params recAlg noveltyEnhance diversityEnhance  \
# 0  attributeCosineSim  noSameObjects   last             no               no
# 1  attributeCosineSim  noSameObjects   last             no              yes
# 2  attributeCosineSim  noSameObjects   last            yes               no
# 3  attributeCosineSim  noSameObjects   last            yes              yes
# 4  attributeCosineSim  noSameObjects    max             no               no
#
#        -mae       auc       mrr   nDCG100  novelty10_t  novelty10_u     ild10
# 0 -0.374933  0.736751  0.134829  0.191740     0.216582     0.998246  0.213208
# 1 -0.374933  0.736751  0.135444  0.193977     0.217033     0.998246  0.240683
# 2 -0.375671  0.738166  0.131909  0.189104     0.222839     0.998772  0.213817
# 3 -0.375671  0.738166  0.133143  0.191978     0.223193     0.998246  0.241725
# 4 -0.422967  0.795054  0.139913  0.214346     0.220340     0.992456  0.272226

# %%
selectedRes = map(lambda x: dfMean.loc[(dfMean.alg == x["name"]) & (dfMean.params == x["params"]) & (dfMean.recAlg == x["aggregation"]) & (dfMean.noveltyEnhance == x["novelty"])  & (dfMean.diversityEnhance == x["diversity"])  ], algVariants )
#selectedRes = map(lambda x: df.loc[(df.alg == x["name"]) ], algVariants )

# %%
lst = list(selectedRes)
lst
# Out:
# [        alg params recAlg noveltyEnhance diversityEnhance      -mae       auc  \
#  82  doc2vec  128,1   last            yes               no -0.292326  0.617363
#
#           mrr   nDCG100  novelty10_t  novelty10_u     ild10
#  82  0.030878  0.056917     0.233531          1.0  0.799611  ,
#          alg params    recAlg noveltyEnhance diversityEnhance      -mae  \
#  93  doc2vec  128,1  temporal             no              yes -0.361817
#
#           auc       mrr   nDCG100  novelty10_t  novelty10_u     ild10
#  93  0.678597  0.031335  0.075085     0.220975     0.996848  0.838122  ,
#           alg params recAlg noveltyEnhance diversityEnhance      -mae  \
#  288  doc2vec   32,5   mean             no               no -0.455116
#
#            auc       mrr   nDCG100  novelty10_t  novelty10_u     ild10
#  288  0.554607  0.028117  0.049527     0.211395     0.997373  0.785867  ,
#           alg params recAlg noveltyEnhance diversityEnhance      -mae  \
#  289  doc2vec   32,5   mean             no              yes -0.455116
#
#            auc       mrr   nDCG100  novelty10_t  novelty10_u     ild10
#  289  0.554607  0.025444  0.046461     0.214064     0.997723  0.859131  ,
#           alg params recAlg noveltyEnhance diversityEnhance      -mae      auc  \
#  166  doc2vec  128,5    max            yes               no -0.213676  0.52555
#
#            mrr   nDCG100  novelty10_t  novelty10_u     ild10
#  166  0.012323  0.031365     0.228605     0.994571  0.740691  ,
#                     alg         params    recAlg noveltyEnhance  \
#  14  attributeCosineSim  noSameObjects  temporal            yes
#
#     diversityEnhance      -mae       auc      mrr   nDCG100  novelty10_t  \
#  14               no -0.405553  0.797143  0.14616  0.215048     0.255013
#
#      novelty10_u     ild10
#  14     0.994386  0.269825  ,
#                     alg       params recAlg noveltyEnhance diversityEnhance  \
#  50  attributeCosineSim  sameAllowed   mean            yes               no
#
#          -mae      auc       mrr   nDCG100  novelty10_t  novelty10_u     ild10
#  50 -0.400451  0.79524  0.149409  0.213611     0.228657     0.993684  0.222901  ,
#                     alg       params    recAlg noveltyEnhance diversityEnhance  \
#  68  attributeCosineSim  sameAllowed  window10             no               no
#
#          -mae       auc       mrr   nDCG100  novelty10_t  novelty10_u     ild10
#  68 -0.389754  0.782645  0.127338  0.204664     0.217543     0.996316  0.208432  ,
#            alg params recAlg noveltyEnhance diversityEnhance      -mae  \
#  769  word2vec   64,5   mean             no              yes -0.413579
#
#            auc       mrr   nDCG100  novelty10_t  novelty10_u     ild10
#  769  0.809344  0.102732  0.182148     0.215008     0.973415  0.683315  ,
#            alg params    recAlg noveltyEnhance diversityEnhance     -mae  \
#  654  word2vec   32,5  temporal            yes               no -0.43821
#
#            auc       mrr   nDCG100  novelty10_t  novelty10_u    ild10
#  654  0.816465  0.102166  0.195187     0.244028     0.976937  0.49472  ,
#            alg params recAlg noveltyEnhance diversityEnhance      -mae  \
#  480  word2vec  128,3   last             no               no -0.289832
#
#            auc       mrr   nDCG100  novelty10_t  novelty10_u    ild10
#  480  0.734258  0.097237  0.167789     0.212053     0.996655  0.53418  ,
#            alg params    recAlg noveltyEnhance diversityEnhance      -mae  \
#  628  word2vec   32,3  window10             no               no -0.432236
#
#            auc      mrr   nDCG100  novelty10_t  novelty10_u    ild10
#  628  0.814319  0.13419  0.228718     0.213729     0.988028  0.44297  ]

# %%
dct = dict([(i, lst[i].iloc[0,:].to_dict()) for i in range(len(lst))])

# %%
dfx = pd.DataFrame.from_dict(dct, orient='index')
dfx.index.name = 'recVariant'
dfx.index.name
# Out:
# 'recVariant'

# %%
#dfx.merge(resOO, on="recVariant")
results = pd.concat([dfx, resOO], axis=1)

# %%
del results["cnt"]
results
# Out:
#                            alg         params    recAlg noveltyEnhance  \
# recVariant
# 0                      doc2vec          128,1      last            yes
# 1                      doc2vec          128,1  temporal             no
# 2                      doc2vec           32,5      mean             no
# 3                      doc2vec           32,5      mean             no
# 4                      doc2vec          128,5       max            yes
# 5           attributeCosineSim  noSameObjects  temporal            yes
# 6           attributeCosineSim    sameAllowed      mean            yes
# 7           attributeCosineSim    sameAllowed  window10             no
# 8                     word2vec           64,5      mean             no
# 9                     word2vec           32,5  temporal            yes
# 10                    word2vec          128,3      last             no
# 11                    word2vec           32,3  window10             no
#
#            diversityEnhance      -mae       auc       mrr   nDCG100  \
# recVariant
# 0                        no -0.292326  0.617363  0.030878  0.056917
# 1                       yes -0.361817  0.678597  0.031335  0.075085
# 2                        no -0.455116  0.554607  0.028117  0.049527
# 3                       yes -0.455116  0.554607  0.025444  0.046461
# 4                        no -0.213676  0.525550  0.012323  0.031365
# 5                        no -0.405553  0.797143  0.146160  0.215048
# 6                        no -0.400451  0.795240  0.149409  0.213611
# 7                        no -0.389754  0.782645  0.127338  0.204664
# 8                       yes -0.413579  0.809344  0.102732  0.182148
# 9                        no -0.438210  0.816465  0.102166  0.195187
# 10                       no -0.289832  0.734258  0.097237  0.167789
# 11                       no -0.432236  0.814319  0.134190  0.228718
#
#             novelty10_t  novelty10_u     ild10       ctr       vrr
# recVariant
# 0              0.233531     1.000000  0.799611  0.006424  0.035332
# 1              0.220975     0.996848  0.838122  0.007890  0.045694
# 2              0.211395     0.997373  0.785867  0.009268  0.051639
# 3              0.214064     0.997723  0.859131  0.006709  0.043450
# 4              0.228605     0.994571  0.740691  0.005295  0.058570
# 5              0.255013     0.994386  0.269825  0.004914  0.015152
# 6              0.228657     0.993684  0.222901  0.010658  0.082835
# 7              0.217543     0.996316  0.208432  0.006917  0.068310
# 8              0.215008     0.973415  0.683315  0.008230  0.050558
# 9              0.244028     0.976937  0.494720  0.006635  0.045667
# 10             0.212053     0.996655  0.534180  0.009694  0.061601
# 11             0.213729     0.988028  0.442970  0.005148  0.138996

# %%
print(results.loc[results.noveltyEnhance == "yes"][["ctr","vrr"]].mean())
print(results.loc[results.noveltyEnhance == "no"][["ctr","vrr"]].mean())

print(results.loc[results.diversityEnhance == "yes"][["ctr","vrr"]].mean())
print(results.loc[results.diversityEnhance == "no"][["ctr","vrr"]].mean())
# Out:
# ctr    0.006785
# vrr    0.047511
# dtype: float64
# ctr    0.007694
# vrr    0.065750
# dtype: float64
# ctr    0.007610
# vrr    0.046568
# dtype: float64
# ctr    0.007217
# vrr    0.062011
# dtype: float64

# %%
resultsX = results[['-mae',
 'auc',
 'mrr',
 'nDCG100',
 'novelty10_t',
 'novelty10_u',
 'ild10',
 'ctr',
 'vrr']]
fig, (ax1, ax2) = plt.subplots(1,2,  figsize=(5, 4))

sns.heatmap(resultsX.corr()[["ctr","vrr"]], annot=True, cbar=False, ax = ax1) #method='spearman'
ax1.set_xticks(np.asarray(range(len(resultsX[["ctr","vrr"]].columns)))+0.5, minor=False)
ax1.set_xticklabels(resultsX[["ctr","vrr"]].columns)

ax1.set_yticks(np.asarray(range(len(resultsX.columns)))+0.5, minor=False)
ax1.set_yticklabels(resultsX.columns)

ax1.set(title="Pearson's rho")

sns.heatmap(resultsX.corr(method='spearman')[["ctr","vrr"]], annot=True,  yticklabels=False, ax = ax2) #method='spearman'
ax2.set_xticks(np.asarray(range(len(resultsX[["ctr","vrr"]].columns)))+0.5, minor=False)
ax2.set_xticklabels(resultsX[["ctr","vrr"]].columns)

ax2.set(title="Spearman's rho")

#ax2.set_yticks(np.asarray(range(len(resultsX.columns)))+0.5, minor=False)
#ax2.set_yticklabels(resultsX.columns)
# Out:
# [Text(0.5,1,"Spearman's rho")]

# %%
resultsX = results[['-mae',
 'auc',
 'mrr',
 'nDCG100',
 'novelty10_t',
 'novelty10_u',
 'ild10',
 'ctr',
 'vrr']]
fig, ax = plt.subplots(figsize=(2.5, 5))

ax = sns.heatmap(resultsX.corr(method='spearman')[["ctr","vrr"]], annot=True) #method='spearman'
ax.set_xticks(np.asarray(range(len(resultsX[["ctr","vrr"]].columns)))+0.5, minor=False)
ax.set_xticklabels(resultsX[["ctr","vrr"]].columns)

ax.set_yticks(np.asarray(range(len(resultsX.columns)))+0.5, minor=False)
ax.set_yticklabels(resultsX.columns)
# Out:
# [Text(0,0.5,'-mae'),
#  Text(0,1.5,'auc'),
#  Text(0,2.5,'mrr'),
#  Text(0,3.5,'nDCG100'),
#  Text(0,4.5,'novelty10_t'),
#  Text(0,5.5,'novelty10_u'),
#  Text(0,6.5,'ild10'),
#  Text(0,7.5,'ctr'),
#  Text(0,8.5,'vrr')]

# %%
from sklearn.linear_model import LinearRegression

lm_ctr = LinearRegression(fit_intercept=True, normalize=False)

lm_ctr.fit(resultsX[['-mae',
 'auc',
 'mrr',
 'nDCG100',
 'novelty10_t',
 'novelty10_u',
 'ild10']], resultsX["ctr"])

print(lm_ctr.coef_ )
print(lm_ctr.intercept_ )
# Out:
# [ 3.08837467e-05  3.75348474e-02  1.15040185e-01 -1.39602485e-01
#  -1.04089089e-01 -5.77636571e-02 -4.99345300e-03]
# 0.07427106857870425

# %%
lm_vrr = LinearRegression(fit_intercept=True, normalize=False)

lm_vrr.fit(resultsX[['-mae',
 'auc',
 'mrr',
 'nDCG100',
 'novelty10_t',
 'novelty10_u',
 'ild10']], resultsX["vrr"])

print(lm_vrr.coef_ )
print(lm_vrr.intercept_ )
# Out:
# [ 0.04485775 -0.35590497 -0.78928341  1.26958348 -1.11191348  0.25261289
#   0.01230443]
# 0.20727845526782215

# %%
from pyearth import Earth

# %%
X = resultsX[['-mae',
 'auc',
 'mrr',
 'nDCG100',
 'novelty10_t',
 'novelty10_u',
 'ild10']]
y =  resultsX["vrr"]

model = Earth(max_terms=10, max_degree=2, penalty = 0.5)
model.fit(X,y)
    
#Print the model
print(model.trace())
print(model.summary())
# Out:
# Forward Pass
# -----------------------------------------------------------------
# iter  parent  var  knot  mse       terms  gcv    rsq    grsq
# -----------------------------------------------------------------
# 0     -       -    -     0.000855  1      0.001  0.000  0.000
# 1     0       4    -1    0.000650  2      0.001  0.239  0.032
# 2     0       3    -1    0.000432  3      0.001  0.494  0.153
# 3     2       3    -1    0.000193  4      0.001  0.775  0.482
# 4     1       2    -1    0.000119  5      0.000  0.860  0.530
# 5     2       2    -1    0.000079  6      0.001  0.908  0.505
# 6     2       1    -1    0.000072  7      0.001  0.916  0.167
# 7     1       6    -1    0.000061  8      0.002  0.928  -0.715
# 8     1       4    -1    0.000036  9      0.005  0.958  -4.127
# 9     1       3    -1    0.000024  10     0.055  0.972  -53.248
# -----------------------------------------------------------------
# Stopping Condition 3: GRSQ too low
#
# Pruning Pass
# ----------------------------------------------
# iter  bf  terms  mse   gcv    rsq    grsq
# ----------------------------------------------
# 0     -   10     0.00  0.055  0.972  -53.248
# 1     5   9      0.00  0.004  0.968  -2.864
# 2     2   8      0.00  0.001  0.965  0.161
# 3     9   7      0.00  0.001  0.943  0.439
# 4     4   6      0.00  0.000  0.928  0.615
# 5     7   5      0.00  0.001  0.828  0.422
# 6     1   4      0.00  0.001  0.723  0.362
# 7     6   3      0.00  0.001  0.574  0.286
# 8     3   2      0.00  0.001  0.243  0.036
# 9     8   1      0.00  0.001  0.000  0.000
# ----------------------------------------------
# Selected iteration: 4
#
# Earth Model
# ----------------------------------------------
# Basis Function           Pruned  Coefficient
# ----------------------------------------------
# (Intercept)              No      -3.32045
# novelty10_t              No      30.202
# nDCG100                  Yes     None
# nDCG100*nDCG100          No      9.16969
# mrr*novelty10_t          Yes     None
# mrr*nDCG100              Yes     None
# auc*nDCG100              No      -2.13581
# ild10*novelty10_t        No      0.452783
# novelty10_t*novelty10_t  No      -68.4509
# nDCG100*novelty10_t      Yes     None
# ----------------------------------------------
# MSE: 0.0001, GCV: 0.0004, RSQ: 0.9281, GRSQ: 0.6145
# C:\Users\peska\Anaconda3\lib\site-packages\pyearth\earth.py:802: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   pruning_passer.run()
# C:\Users\peska\Anaconda3\lib\site-packages\pyearth\earth.py:1055: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   coef, resid = np.linalg.lstsq(B, weighted_y[:, i])[0:2]

# %%
from matplotlib import pyplot
y_hat = model.predict(X)
pyplot.figure()
pyplot.plot(y_hat,y,'r.')

pyplot.title('Simple Earth Example')
pyplot.show()

# %%
Xall = dfMean[['-mae',
 'auc',
 'mrr',
 'nDCG100',
 'novelty10_t',
 'novelty10_u',
 'ild10']]

# %%
y_hatMars = model.predict(Xall)

# %%
y_hatLM = lm_vrr.predict(Xall)

# %%
len(y_hatMars)
# Out:
# 800

# %%
dfMean["vrr_hat_MARS"] = y_hatMars
dfMean["vrr_hat_LM"] = y_hatLM
dfMean.head()
# Out:
#                   alg         params recAlg noveltyEnhance diversityEnhance  \
# 0  attributeCosineSim  noSameObjects   last             no               no
# 1  attributeCosineSim  noSameObjects   last             no              yes
# 2  attributeCosineSim  noSameObjects   last            yes               no
# 3  attributeCosineSim  noSameObjects   last            yes              yes
# 4  attributeCosineSim  noSameObjects    max             no               no
#
#    vrr_hat_MARS  vrr_hat_LM
# 0      0.066200    0.079231
# 1      0.073571    0.081422
# 2      0.062008    0.070836
# 3      0.070259    0.073327
# 4      0.095472    0.076097

# %%
dfMean = dfMean[["alg","params","recAlg","noveltyEnhance","diversityEnhance","vrr_hat_MARS","vrr_hat_LM"]]

# %%
dfMean[["vrr_hat_MARS","vrr_hat_LM"]].corr()
# Out:
#               vrr_hat_MARS  vrr_hat_LM
# vrr_hat_MARS       1.00000     0.86048
# vrr_hat_LM         0.86048     1.00000

# %%
dfMean[["vrr_hat_MARS","vrr_hat_LM"]].corr(method="spearman")
# Out:
#               vrr_hat_MARS  vrr_hat_LM
# vrr_hat_MARS      1.000000    0.743661
# vrr_hat_LM        0.743661    1.000000

# %%
dfGroup = dfMean.groupby(by=["alg"])
dfMean2 = dfGroup.mean()
dfMean2
# Out:
#                     vrr_hat_MARS  vrr_hat_LM
# alg
# attributeCosineSim      0.076313    0.067553
# doc2vec                 0.012935    0.030910
# word2vec                0.045593    0.070758

# %%
dfGroup = dfMean.groupby(by=["alg","params","recAlg","noveltyEnhance","diversityEnhance"])
dfMax = dfGroup.mean()
dfMax = dfMax.groupby(by=["alg"])
dfMax.max()
# Out:
#                     vrr_hat_MARS  vrr_hat_LM
# alg
# attributeCosineSim      0.163113    0.089776
# doc2vec                 0.072925    0.067795
# word2vec                0.132518    0.104342

# %%
dfGroup = dfMean.groupby(by=["recAlg"])
dfMean2 = dfGroup.mean()
dfMean2
# Out:
#             vrr_hat_MARS  vrr_hat_LM
# recAlg
# last            0.058351    0.068409
# max             0.047734    0.063624
# mean            0.065790    0.055456
# temporal       -0.019981    0.027926
# temporal10     -0.008527    0.034862
# temporal3       0.010795    0.043797
# temporal5       0.004799    0.040660
# window10        0.061013    0.061458
# window3         0.059644    0.065259
# window5         0.060074    0.063611

# %%
print(dfMean2.loc[dfMean2.index.isin( ["mean","temporal","temporal10","window10"])][["vrr_hat_MARS","vrr_hat_LM"]].mean())
print(dfMean2.loc[dfMean2.index.isin(["last","temporal3","temporal5","window3","window5"])][["vrr_hat_MARS","vrr_hat_LM"]].mean())

print(dfMean2.loc[dfMean2.index.isin( ["temporal3","temporal5","temporal10"])][["vrr_hat_MARS","vrr_hat_LM"]].mean())
print(dfMean2.loc[dfMean2.index.isin(["window3","window5","window10"])][["vrr_hat_MARS","vrr_hat_LM"]].mean())
# Out:
# vrr_hat_MARS    0.024574
# vrr_hat_LM      0.044925
# dtype: float64
# vrr_hat_MARS    0.038733
# vrr_hat_LM      0.056347
# dtype: float64
# vrr_hat_MARS    0.002356
# vrr_hat_LM      0.039773
# dtype: float64
# vrr_hat_MARS    0.060244
# vrr_hat_LM      0.063443
# dtype: float64

# %%
dfGroup = dfMean.groupby(by=["alg","params","recAlg","noveltyEnhance","diversityEnhance"])
dfMax = dfGroup.mean()
dfMax = dfMax.groupby(by=["recAlg"])
dm = dfMax.max()
dm
# Out:
#             vrr_hat_MARS  vrr_hat_LM
# recAlg
# last            0.094466    0.102836
# max             0.116970    0.097624
# mean            0.156765    0.092417
# temporal        0.163113    0.093417
# temporal10      0.147757    0.101046
# temporal3       0.139065    0.102328
# temporal5       0.134746    0.099949
# window10        0.132518    0.102274
# window3         0.113199    0.103287
# window5         0.124868    0.104342

# %%
print(dm.loc[dm.index.isin( ["mean","temporal","temporal10","window10"])][["vrr_hat_MARS","vrr_hat_LM"]].max())
print(dm.loc[dm.index.isin(["last","temporal3","temporal5","window3","window5"])][["vrr_hat_MARS","vrr_hat_LM"]].max())

print(dm.loc[dm.index.isin( ["temporal3","temporal5","temporal10"])][["vrr_hat_MARS","vrr_hat_LM"]].mean())
print(dm.loc[dm.index.isin(["window3","window5","window10"])][["vrr_hat_MARS","vrr_hat_LM"]].mean())
# Out:
# vrr_hat_MARS    0.163113
# vrr_hat_LM      0.102274
# dtype: float64
# vrr_hat_MARS    0.139065
# vrr_hat_LM      0.104342
# dtype: float64
# vrr_hat_MARS    0.140523
# vrr_hat_LM      0.101108
# dtype: float64
# vrr_hat_MARS    0.123528
# vrr_hat_LM      0.103301
# dtype: float64

# %%
dfGroup = dfMean.groupby(by=["noveltyEnhance"])
dfMean2 = dfGroup.mean()
dfMean2
# Out:
#                 vrr_hat_MARS  vrr_hat_LM
# noveltyEnhance
# no                  0.062531    0.070564
# yes                 0.005408    0.034448

# %%
dfGroup = dfMean.groupby(by=["alg","params","recAlg","noveltyEnhance","diversityEnhance"])
dfMax = dfGroup.mean()
dfMax = dfMax.groupby(by=["noveltyEnhance"])
dfMax.max()
# Out:
#                 vrr_hat_MARS  vrr_hat_LM
# noveltyEnhance
# no                  0.163113    0.104342
# yes                 0.140482    0.097352

# %%
dfGroup = dfMean.groupby(by=["diversityEnhance"])
dfMean2 = dfGroup.mean()
dfMean2
# Out:
#                   vrr_hat_MARS  vrr_hat_LM
# diversityEnhance
# no                    0.031498    0.054399
# yes                   0.036441    0.050613

# %%
dfGroup = dfMean.groupby(by=["alg","params","recAlg","noveltyEnhance","diversityEnhance"])
dfMax = dfGroup.mean()
dfMax = dfMax.groupby(by=["diversityEnhance"])
dfMax.max()
# Out:
#                   vrr_hat_MARS  vrr_hat_LM
# diversityEnhance
# no                    0.146009    0.104342
# yes                   0.163113    0.093224

# %%
dfGroup = dfMean.groupby(by=["alg","params"])
dfMean2 = dfGroup.mean()
dfMean2
# Out:
#                                   vrr_hat_MARS  vrr_hat_LM
# alg                params
# attributeCosineSim noSameObjects      0.097592    0.065709
#                    sameAllowed        0.055035    0.069397
# doc2vec            128,1             -0.015049    0.015372
#                    128,3              0.013349    0.040044
#                    128,5              0.015779    0.035350
#                    32,1               0.001014    0.021990
#                    32,3               0.028657    0.032181
#                    32,5               0.031854    0.041824
#                    64,1              -0.007446    0.018081
#                    64,3               0.023259    0.035406
#                    64,5               0.024999    0.037944
# word2vec           128,1              0.007554    0.059466
#                    128,3              0.021993    0.066642
#                    128,5              0.032931    0.068016
#                    32,1               0.072691    0.080788
#                    32,3               0.082912    0.079666
#                    32,5               0.073582    0.080808
#                    64,1               0.026829    0.065044
#                    64,3               0.051959    0.070664
#                    64,5               0.039889    0.065732

# %%
dfGroup = dfMean.groupby(by=["alg","params","recAlg","noveltyEnhance","diversityEnhance"])
dfMax = dfGroup.mean()
dfMax = dfMax.groupby(by=["alg","params"])
dfMax.max()
# Out:
#                                   vrr_hat_MARS  vrr_hat_LM
# alg                params
# attributeCosineSim noSameObjects      0.163113    0.084062
#                    sameAllowed        0.098901    0.089776
# doc2vec            128,1              0.054990    0.046613
#                    128,3              0.069427    0.065811
#                    128,5              0.072925    0.065001
#                    32,1               0.046755    0.045692
#                    32,3               0.063300    0.054697
#                    32,5               0.065040    0.067795
#                    64,1               0.053225    0.050030
#                    64,3               0.070918    0.062753
#                    64,5               0.070239    0.066870
# word2vec           128,1              0.056737    0.095797
#                    128,3              0.066472    0.095709
#                    128,5              0.084109    0.101046
#                    32,1               0.110673    0.104342
#                    32,3               0.132518    0.103287
#                    32,5               0.111996    0.102328
#                    64,1               0.059195    0.093169
#                    64,3               0.094355    0.097557
#                    64,5               0.073442    0.088736

# %%
dfMean.sort_values(by="vrr_hat_MARS", ascending=False, inplace=True)
dfMean.head(50)
# Out:
#                     alg         params      recAlg noveltyEnhance  \
# 13   attributeCosineSim  noSameObjects    temporal             no
# 9    attributeCosineSim  noSameObjects        mean             no
# 17   attributeCosineSim  noSameObjects  temporal10             no
# 12   attributeCosineSim  noSameObjects    temporal             no
# 8    attributeCosineSim  noSameObjects        mean             no
# 11   attributeCosineSim  noSameObjects        mean            yes
# 16   attributeCosineSim  noSameObjects  temporal10             no
# 21   attributeCosineSim  noSameObjects   temporal3             no
# 25   attributeCosineSim  noSameObjects   temporal5             no
# 628            word2vec           32,3    window10             no
# 24   attributeCosineSim  noSameObjects   temporal5             no
# 10   attributeCosineSim  noSameObjects        mean            yes
# 29   attributeCosineSim  noSameObjects    window10             no
# 630            word2vec           32,3    window10            yes
# 37   attributeCosineSim  noSameObjects     window5             no
# 612            word2vec           32,3    temporal             no
# 20   attributeCosineSim  noSameObjects   temporal3             no
# 616            word2vec           32,3  temporal10             no
# 608            word2vec           32,3        mean             no
# 28   attributeCosineSim  noSameObjects    window10             no
# 636            word2vec           32,3     window5             no
# 5    attributeCosineSim  noSameObjects         max             no
# 610            word2vec           32,3        mean            yes
# 7    attributeCosineSim  noSameObjects         max            yes
# 624            word2vec           32,3   temporal5             no
# 33   attributeCosineSim  noSameObjects     window3             no
# 638            word2vec           32,3     window5            yes
# 652            word2vec           32,5    temporal             no
# 648            word2vec           32,5        mean             no
# 36   attributeCosineSim  noSameObjects     window5             no
# 588            word2vec           32,1    window10             no
# 650            word2vec           32,5        mean            yes
# 576            word2vec           32,1  temporal10             no
# 572            word2vec           32,1    temporal             no
# 656            word2vec           32,5  temporal10             no
# 31   attributeCosineSim  noSameObjects    window10            yes
# 30   attributeCosineSim  noSameObjects    window10            yes
# 570            word2vec           32,1        mean            yes
# 568            word2vec           32,1        mean             no
# 32   attributeCosineSim  noSameObjects     window3             no
# 590            word2vec           32,1    window10            yes
# 39   attributeCosineSim  noSameObjects     window5            yes
# 38   attributeCosineSim  noSameObjects     window5            yes
# 668            word2vec           32,5    window10             no
# 670            word2vec           32,5    window10            yes
# 620            word2vec           32,3   temporal3             no
# 632            word2vec           32,3     window3             no
# 609            word2vec           32,3        mean             no
# 35   attributeCosineSim  noSameObjects     window3            yes
# 611            word2vec           32,3        mean            yes
#
#     diversityEnhance  vrr_hat_MARS  vrr_hat_LM
# 13               yes      0.163113    0.076177
# 9                yes      0.156765    0.074123
# 17               yes      0.147757    0.077284
# 12                no      0.146009    0.077107
# 8                 no      0.140579    0.075448
# 11               yes      0.140482    0.058035
# 16                no      0.140391    0.080348
# 21               yes      0.139065    0.081370
# 25               yes      0.134746    0.082804
# 628               no      0.132518    0.099923
# 24                no      0.129628    0.084062
# 10                no      0.129547    0.060521
# 29               yes      0.129196    0.075703
# 630               no      0.126986    0.087293
# 37               yes      0.124868    0.076965
# 612               no      0.124409    0.092231
# 20                no      0.124408    0.081403
# 616               no      0.121984    0.095475
# 608               no      0.119926    0.087576
# 28                no      0.117574    0.076225
# 636               no      0.117284    0.102331
# 5                yes      0.116970    0.077181
# 610               no      0.116629    0.078673
# 7                yes      0.116195    0.067322
# 624               no      0.113400    0.098100
# 33               yes      0.113199    0.079557
# 638               no      0.112206    0.090457
# 652               no      0.111996    0.093417
# 648               no      0.111582    0.092417
# 36                no      0.111491    0.076276
# 588               no      0.110673    0.101119
# 650               no      0.110590    0.082615
# 576               no      0.110318    0.093980
# 572               no      0.109934    0.091115
# 656               no      0.109707    0.099467
# 31               yes      0.108672    0.060163
# 30                no      0.107658    0.063489
# 570               no      0.107443    0.081928
# 568               no      0.107264    0.089845
# 32                no      0.106538    0.079456
# 590               no      0.105316    0.090985
# 39               yes      0.104693    0.062174
# 38                no      0.104629    0.066647
# 668               no      0.104480    0.102274
# 670               no      0.103700    0.090532
# 620               no      0.102039    0.100453
# 632               no      0.101017    0.103287
# 609              yes      0.100414    0.077980
# 35               yes      0.100104    0.067391
# 611              yes      0.099734    0.068975

# %%
dfMean.sort_values(by="vrr_hat_LM", ascending=False, inplace=True)
dfMean.head(50)
# Out:
#           alg params      recAlg noveltyEnhance diversityEnhance  \
# 596  word2vec   32,1     window5             no               no
# 632  word2vec   32,3     window3             no               no
# 600  word2vec   32,3        last             no               no
# 592  word2vec   32,1     window3             no               no
# 636  word2vec   32,3     window5             no               no
# 660  word2vec   32,5   temporal3             no               no
# 668  word2vec   32,5    window10             no               no
# 588  word2vec   32,1    window10             no               no
# 672  word2vec   32,5     window3             no               no
# 536  word2vec  128,5  temporal10             no               no
# 548  word2vec  128,5    window10             no               no
# 620  word2vec   32,3   temporal3             no               no
# 584  word2vec   32,1   temporal5             no               no
# 628  word2vec   32,3    window10             no               no
# 676  word2vec   32,5     window5             no               no
# 556  word2vec  128,5     window5             no               no
# 656  word2vec   32,5  temporal10             no               no
# 552  word2vec  128,5     window3             no               no
# 544  word2vec  128,5   temporal5             no               no
# 624  word2vec   32,3   temporal5             no               no
# 580  word2vec   32,1   temporal3             no               no
# 664  word2vec   32,5   temporal5             no               no
# 604  word2vec   32,3         max             no               no
# 740  word2vec   64,3   temporal3             no               no
# 602  word2vec   32,3        last            yes               no
# 756  word2vec   64,3     window5             no               no
# 540  word2vec  128,5   temporal3             no               no
# 752  word2vec   64,3     window3             no               no
# 640  word2vec   32,5        last             no               no
# 560  word2vec   32,1        last             no               no
# 744  word2vec   64,3   temporal5             no               no
# 468  word2vec  128,1    window10             no               no
# 504  word2vec  128,3   temporal5             no               no
# 616  word2vec   32,3  temporal10             no               no
# 748  word2vec   64,3    window10             no               no
# 634  word2vec   32,3     window3            yes               no
# 516  word2vec  128,3     window5             no               no
# 500  word2vec  128,3   temporal3             no               no
# 476  word2vec  128,1     window5             no               no
# 598  word2vec   32,1     window5            yes               no
# 594  word2vec   32,1     window3            yes               no
# 576  word2vec   32,1  temporal10             no               no
# 508  word2vec  128,3    window10             no               no
# 720  word2vec   64,3        last             no               no
# 456  word2vec  128,1  temporal10             no               no
# 652  word2vec   32,5    temporal             no               no
# 520  word2vec  128,5        last             no               no
# 464  word2vec  128,1   temporal5             no               no
# 496  word2vec  128,3  temporal10             no               no
# 597  word2vec   32,1     window5             no              yes
#
#      vrr_hat_MARS  vrr_hat_LM
# 596      0.097139    0.104342
# 632      0.101017    0.103287
# 600      0.094466    0.102836
# 592      0.088682    0.102552
# 636      0.117284    0.102331
# 660      0.089649    0.102328
# 668      0.104480    0.102274
# 588      0.110673    0.101119
# 672      0.083013    0.101103
# 536      0.077138    0.101046
# 548      0.074584    0.100540
# 620      0.102039    0.100453
# 584      0.094224    0.099949
# 628      0.132518    0.099923
# 676      0.089137    0.099719
# 556      0.071239    0.099508
# 656      0.109707    0.099467
# 552      0.071999    0.099214
# 544      0.068787    0.098338
# 624      0.113400    0.098100
# 580      0.079250    0.097950
# 664      0.099408    0.097715
# 604      0.058708    0.097624
# 740      0.069501    0.097557
# 602      0.092922    0.097352
# 756      0.071267    0.097250
# 540      0.070032    0.097045
# 752      0.067380    0.096969
# 640      0.080180    0.096742
# 560      0.082532    0.096435
# 744      0.075037    0.096055
# 468      0.049281    0.095797
# 504      0.055809    0.095709
# 616      0.121984    0.095475
# 748      0.084329    0.094984
# 634      0.099440    0.094728
# 516      0.053995    0.094704
# 500      0.057408    0.094549
# 476      0.047447    0.094548
# 598      0.092069    0.094526
# 594      0.088061    0.094102
# 576      0.110318    0.093980
# 508      0.054004    0.093840
# 720      0.073599    0.093709
# 456      0.052709    0.093486
# 652      0.111996    0.093417
# 520      0.069185    0.093408
# 464      0.046039    0.093293
# 496      0.057312    0.093257
# 597      0.073141    0.093224
